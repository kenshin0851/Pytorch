# %% [markdown]
# # `Deepfake Classification - ViT`

# %%
# !pip install evaluate datasets accelerate
# !pip install git+https://github.com/huggingface/transformers.git
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Collecting datasets
#   Downloading datasets-4.4.0-py3-none-any.whl.metadata (19 kB)
# Collecting accelerate
#   Downloading accelerate-1.11.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.17 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from evaluate) (1.26.4)
# Requirement already satisfied: dill in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from evaluate) (2.2.3)
# Requirement already satisfied: requests>=2.19.0 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from evaluate) (4.67.1)
# Collecting xxhash (from evaluate)
#   Downloading xxhash-3.6.0-cp310-cp310-manylinux2014_aarch64.manylinux_2_17_aarch64.manylinux_2_28_aarch64.whl.metadata (13 kB)
# Collecting multiprocess (from evaluate)
#   Downloading multiprocess-0.70.18-py310-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: fsspec>=2021.05.0 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.2)
# Collecting huggingface-hub>=0.7.0 (from evaluate)
#   Downloading huggingface_hub-1.0.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from evaluate) (24.2)
# Requirement already satisfied: filelock in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from datasets) (3.17.0)
# Collecting pyarrow>=21.0.0 (from datasets)
#   Downloading pyarrow-22.0.0-cp310-cp310-manylinux_2_28_aarch64.whl.metadata (3.2 kB)
# Requirement already satisfied: httpx<1.0.0 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from fsspec[http]>=2021.05.0->evaluate) (3.11.10)
# Requirement already satisfied: anyio in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (4.7.0)
# Requirement already satisfied: certifi in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (3.7)
# Requirement already satisfied: h11>=0.16 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Collecting shellingham (from huggingface-hub>=0.7.0->evaluate)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting typer-slim (from huggingface-hub>=0.7.0->evaluate)
#   Downloading typer_slim-0.20.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from huggingface-hub>=0.7.0->evaluate) (4.12.2)
# Collecting hf-xet<2.0.0,>=1.2.0 (from huggingface-hub>=0.7.0->evaluate)
#   Downloading hf_xet-1.2.0-cp37-abi3-manylinux_2_28_aarch64.whl.metadata (4.9 kB)
# Collecting dill (from evaluate)
#   Downloading dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: psutil in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: torch>=2.0.0 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from accelerate) (2.5.0a0+872d972e41.nv24.8)
# Collecting safetensors>=0.4.3 (from accelerate)
#   Downloading safetensors-0.6.2-cp38-abi3-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (4.1 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.18.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (5.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: networkx in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: sympy==1.13.1 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from anyio->httpx<1.0.0->datasets) (1.2.0)
# Requirement already satisfied: sniffio>=1.1 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from anyio->httpx<1.0.0->datasets) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Requirement already satisfied: click>=8.0.0 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from typer-slim->huggingface-hub>=0.7.0->evaluate) (8.1.8)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
# Downloading datasets-4.4.0-py3-none-any.whl (511 kB)
# Downloading huggingface_hub-1.0.1-py3-none-any.whl (503 kB)
# Downloading hf_xet-1.2.0-cp37-abi3-manylinux_2_28_aarch64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 11.0 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading multiprocess-0.70.18-py310-none-any.whl (134 kB)
# Downloading dill-0.4.0-py3-none-any.whl (119 kB)
# Downloading accelerate-1.11.0-py3-none-any.whl (375 kB)
# Downloading pyarrow-22.0.0-cp310-cp310-manylinux_2_28_aarch64.whl (45.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 MB 11.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading safetensors-0.6.2-cp38-abi3-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (473 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading typer_slim-0.20.0-py3-none-any.whl (47 kB)
# Downloading xxhash-3.6.0-cp310-cp310-manylinux2014_aarch64.manylinux_2_17_aarch64.manylinux_2_28_aarch64.whl (212 kB)
# Installing collected packages: xxhash, typer-slim, shellingham, safetensors, pyarrow, hf-xet, dill, multiprocess, huggingface-hub, accelerate, datasets, evaluate
#   Attempting uninstall: pyarrow╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/12 [safetensors]
#     Found existing installation: pyarrow 19.0.0━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/12 [safetensors]
#     Uninstalling pyarrow-19.0.0:╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/12 [safetensors]
#       Successfully uninstalled pyarrow-19.0.0237m╺━━━━━━━━━━━━━━━━━━━━━━━━━━  4/12 [pyarrow]
#   Attempting uninstall: dill━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━  4/12 [pyarrow]
#     Found existing installation: dill 0.3.87m╺━━━━━━━━━━━━━━━━━━━━━━━━━━  4/12 [pyarrow]
#     Uninstalling dill-0.3.8:━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━  4/12 [pyarrow]
#       Successfully uninstalled dill-0.3.8237m╺━━━━━━━━━━━━━━━━━━━━━━━━━━  4/12 [pyarrow]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/12 [evaluate] 10/12 [datasets]e]ingface-hub]
# Successfully installed accelerate-1.11.0 datasets-4.4.0 dill-0.4.0 evaluate-0.4.6 hf-xet-1.2.0 huggingface-hub-1.0.1 multiprocess-0.70.18 pyarrow-22.0.0 safetensors-0.6.2 shellingham-1.5.4 typer-slim-0.20.0 xxhash-3.6.0
# Collecting git+https://github.com/huggingface/transformers.git
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-ce0f20c4
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-ce0f20c4
#   Resolved https://github.com/huggingface/transformers.git to commit 36b640562b11f54044841ae3665930023d4ff27d
#   Installing build dependencies ... one
#   Getting requirements to build wheel ... one
#   Preparing metadata (pyproject.toml) ... one
# Requirement already satisfied: filelock in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from transformers==5.0.0.dev0) (3.17.0)
# Collecting huggingface-hub==1.0.0.rc6 (from transformers==5.0.0.dev0)
#   Downloading huggingface_hub-1.0.0rc6-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from transformers==5.0.0.dev0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from transformers==5.0.0.dev0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from transformers==5.0.0.dev0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from transformers==5.0.0.dev0) (2024.11.6)
# Requirement already satisfied: requests in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from transformers==5.0.0.dev0) (2.32.3)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers==5.0.0.dev0)
#   Downloading tokenizers-0.22.1-cp39-abi3-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (6.8 kB)
# Requirement already satisfied: typer-slim in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from transformers==5.0.0.dev0) (0.20.0)
# Requirement already satisfied: safetensors>=0.4.3 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from transformers==5.0.0.dev0) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from transformers==5.0.0.dev0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from huggingface-hub==1.0.0.rc6->transformers==5.0.0.dev0) (2025.3.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from huggingface-hub==1.0.0.rc6->transformers==5.0.0.dev0) (0.28.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from huggingface-hub==1.0.0.rc6->transformers==5.0.0.dev0) (4.12.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from huggingface-hub==1.0.0.rc6->transformers==5.0.0.dev0) (1.2.0)
# Requirement already satisfied: anyio in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface-hub==1.0.0.rc6->transformers==5.0.0.dev0) (4.7.0)
# Requirement already satisfied: certifi in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface-hub==1.0.0.rc6->transformers==5.0.0.dev0) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface-hub==1.0.0.rc6->transformers==5.0.0.dev0) (1.0.9)
# Requirement already satisfied: idna in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface-hub==1.0.0.rc6->transformers==5.0.0.dev0) (3.7)
# Requirement already satisfied: h11>=0.16 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub==1.0.0.rc6->transformers==5.0.0.dev0) (0.16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub==1.0.0.rc6->transformers==5.0.0.dev0) (1.2.0)
# Requirement already satisfied: sniffio>=1.1 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub==1.0.0.rc6->transformers==5.0.0.dev0) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from requests->transformers==5.0.0.dev0) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from requests->transformers==5.0.0.dev0) (2.5.0)
# Requirement already satisfied: click>=8.0.0 in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages (from typer-slim->transformers==5.0.0.dev0) (8.1.8)
# Downloading huggingface_hub-1.0.0rc6-py3-none-any.whl (502 kB)
# Downloading tokenizers-0.22.1-cp39-abi3-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 10.8 MB/s eta 0:00:0031m11.8 MB/s eta 0:00:01
# Building wheels for collected packages: transformers
#   Buildindone
#   Created wheel for transformers: filename=transformers-5.0.0.dev0-py3-none-any.whl size=11358722 sha256=55d686afd6faf21b2a54b03f00b294d102669c80e5088e7b0dacc6a871e36b6b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-putv0mdo/wheels/e7/9c/5b/e1a9c8007c343041e61cc484433d512ea9274272e3fcbe7c16
# Successfully built transformers
# Installing collected packages: huggingface-hub, tokenizers, transformers
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 1.0.1
#     Uninstalling huggingface-hub-1.0.1:
#       Successfully uninstalled huggingface-hub-1.0.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [transformers]━━━━━ 2/3 [transformers]
# Successfully installed huggingface-hub-1.0.0rc6 tokenizers-0.22.1 transformers-5.0.0.dev0

# %%
import warnings
warnings.filterwarnings("ignore")

import gc
import numpy as np
import pandas as pd
import itertools
from collections import Counter
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix, classification_report, f1_score
from imblearn.over_sampling import RandomOverSampler
import evaluate
from datasets import Dataset, Image, ClassLabel
from transformers import (
    TrainingArguments,
    Trainer,
    ViTImageProcessor,
    ViTForImageClassification,
    DefaultDataCollator
)
import torch
from torch.utils.data import DataLoader
from torchvision.transforms import (
    CenterCrop,
    Compose,
    Normalize,
    RandomRotation,
    RandomResizedCrop,
    RandomHorizontalFlip,
    RandomAdjustSharpness,
    Resize,
    ToTensor
)
from PIL import Image as PILImage
from PIL import ImageFile

# Enable loading truncated images
ImageFile.LOAD_TRUNCATED_IMAGES = True
# Out:
# 🚨 `image_seq_length` is part of ImagesKwargs, but not documented. Make sure to add it to the docstring of the function in /home/orinnano/anaconda3/envs/py310/lib/python3.10/site-packages/transformers/image_processing_utils_fast.py.

# %%
from datasets import load_dataset
dataset = load_dataset("samples", split="train")

file_names = []
labels = []

for example in dataset:
    file_path = example['image'].filename  # Get the file path
    label = pd.read_csv("/home/orinnano/Downloads/samples/fake/label/label.csv", header=None) # Get the label
    file_names.append(file_path)  # Add the file path to the list
 
labels=[1,1,1,1,1,1,1,0]
# Out:
# Using the latest cached version of the dataset since samples couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'default' at /home/orinnano/.cache/huggingface/datasets/samples/default/0.0.0/0b1262fdfd058bf6 (last modified on Wed Nov  5 22:08:12 2025).

# %%
# Print the total number of file names and labels
print(len(file_names), len(labels))
# Out:
# 8 8

# %%
# Create a pandas dataframe from the collected file names and labels
df = pd.DataFrame.from_dict({"image": file_names, "label": labels})

# %%
print(df.shape)
# Out:
# (8, 2)

# %%
df.head()
# Out:
#                                                image  label
# 0  /home/orinnano/Downloads/samples/fake/image/sa...      1
# 1  /home/orinnano/Downloads/samples/fake/image/sa...      1
# 2  /home/orinnano/Downloads/samples/fake/image/sa...      1
# 3  /home/orinnano/Downloads/samples/fake/image/sa...      1
# 4  /home/orinnano/Downloads/samples/fake/image/sa...      1

# %%
df['label'].unique()
# Out:
# array([1, 0])

# %%
y = df[['label']]
df = df.drop(['label'], axis=1)
ros = RandomOverSampler(random_state=83)
df, y_resampled = ros.fit_resample(df, y)
del y
df['label'] = y_resampled
del y_resampled
gc.collect()
# Out:
# 80

# %%
import pandas as pd

# Create a DataFrame from the collected file names and labels
df = pd.DataFrame.from_dict({"image": file_names, "label": labels})

# %%
dataset[7]["image"]
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=560x315>

# %%
labels_subset = labels[:5]

# Printing the subset of labels to inspect the content.
print(labels_subset)
# Out:
# [1, 1, 1, 1, 1]

# %%
# Define the list of unique labels
labels_list = ['Realism', 'Deepfake']

# Initialize dictionaries to map labels to IDs and vice versa
label2id, id2label = dict(), dict()
for i, label in enumerate(labels_list):
    label2id[label] = i
    id2label[i] = label

# Create ClassLabels object
ClassLabels = ClassLabel(num_classes=len(labels_list), names=labels_list)

# %%
# Print the resulting dictionaries for reference
print("Mapping of IDs to Labels:", id2label, '\n')
print("Mapping of Labels to IDs:", label2id)
# Out:
# Mapping of IDs to Labels: {0: 'Realism', 1: 'Deepfake'}
#
# Mapping of Labels to IDs: {'Realism': 0, 'Deepfake': 1}

# %%
# Mapping labels to IDs
def map_label2id(example):
    example['label'] = ClassLabels.str2int(example['label'])
    return example

dataset = dataset.map(map_label2id, batched=True)

# Casting label column to ClassLabel Object
dataset = dataset.cast_column('label', ClassLabels)

# Splitting the dataset into training and testing sets using an 60-40 split ratio.
dataset = dataset.train_test_split(test_size=0.4, shuffle=True, stratify_by_column="label")

# Extracting the training data from the split dataset.
train_data = dataset['train']

# Extracting the testing data from the split dataset.
test_data = dataset['test']
# Out:
# Map:   0%|          | 0/8 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 6
#       3     example['label'] = ClassLabels.str2int(example['label'])
#       4     return example
# ----> 6 dataset = dataset.map(map_label2id, batched=True)
#       8 # Casting label column to ClassLabel Object
#       9 dataset = dataset.cast_column('label', ClassLabels)
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/datasets/arrow_dataset.py:562, in transmit_format.<locals>.wrapper(*args, **kwargs)
#     555 self_format = {
#     556     "type": self._format_type,
#     557     "format_kwargs": self._format_kwargs,
#     558     "columns": self._format_columns,
#     559     "output_all_columns": self._output_all_columns,
#     560 }
#     561 # apply actual function
# --> 562 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     563 datasets: list["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     564 # re-apply format to the output
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/datasets/arrow_dataset.py:3341, in Dataset.map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, suffix_template, new_fingerprint, desc, try_original_type)
#    3339     else:
#    3340         for unprocessed_kwargs in unprocessed_kwargs_per_job:
# -> 3341             for rank, done, content in Dataset._map_single(**unprocessed_kwargs):
#    3342                 check_if_shard_done(rank, done, content)
#    3344 # Avoids PermissionError on Windows (the error: https://github.com/huggingface/datasets/actions/runs/4026734820/jobs/6921621805)
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/datasets/arrow_dataset.py:3697, in Dataset._map_single(shard, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, new_fingerprint, rank, offset, try_original_type)
#    3695 else:
#    3696     _time = time.time()
# -> 3697     for i, batch in iter_outputs(shard_iterable):
#    3698         num_examples_in_batch = len(i)
#    3699         if update_data:
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/datasets/arrow_dataset.py:3647, in Dataset._map_single.<locals>.iter_outputs(shard_iterable)
#    3645 else:
#    3646     for i, example in shard_iterable:
# -> 3647         yield i, apply_function(example, i, offset=offset)
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/datasets/arrow_dataset.py:3570, in Dataset._map_single.<locals>.apply_function(pa_inputs, indices, offset)
#    3568 """Utility to apply the function on a selection of columns."""
#    3569 inputs, fn_args, additional_args, fn_kwargs = prepare_inputs(pa_inputs, indices, offset=offset)
# -> 3570 processed_inputs = function(*fn_args, *additional_args, **fn_kwargs)
#    3571 return prepare_outputs(pa_inputs, inputs, processed_inputs)
#
# Cell In[14], line 3, in map_label2id(example)
#       2 def map_label2id(example):
# ----> 3     example['label'] = ClassLabels.str2int(example['label'])
#       4     return example
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/datasets/formatting/formatting.py:283, in LazyDict.__getitem__(self, key)
#     282 def __getitem__(self, key):
# --> 283     value = self.data[key]
#     284     if key in self.keys_to_format:
#     285         value = self.format(key)
#
# KeyError: 'label'

# %%
# Define the pre-trained ViT model string
model_str = "google/vit-base-patch16-224-in21k"

# Create a processor for ViT model input
processor = ViTImageProcessor.from_pretrained(model_str)

# Retrieve the image mean and standard deviation used for normalization
image_mean, image_std = processor.image_mean, processor.image_std
size = processor.size["height"]

# Define transformations for training and validation data
_train_transforms = Compose(
    [
        Resize((size, size)),
        RandomRotation(90),
        RandomAdjustSharpness(2),
        ToTensor(),
        Normalize(mean=image_mean, std=image_std)
    ]
)

_val_transforms = Compose(
    [
        Resize((size, size)),
        ToTensor(),
        Normalize(mean=image_mean, std=image_std)
    ]
)

# Define functions to apply transformations
def train_transforms(examples):
    examples['pixel_values'] = [_train_transforms(image.convert("RGB")) for image in examples['image']]
    return examples

def val_transforms(examples):
    examples['pixel_values'] = [_val_transforms(image.convert("RGB")) for image in examples['image']]
    return examples

# Set transforms for training and test data
train_data.set_transform(train_transforms)
test_data.set_transform(val_transforms)
# Out:
# preprocessor_config.json:   0%|          | 0.00/160 [00:00<?, ?B/s]

# %%
def collate_fn(examples):
    pixel_values = torch.stack([example["pixel_values"] for example in examples])
    labels = torch.tensor([example['label'] for example in examples])
    return {"pixel_values": pixel_values, "labels": labels}

# %%
# Create a ViTForImageClassification model
model = ViTForImageClassification.from_pretrained(model_str, num_labels=len(labels_list))
model.config.id2label = id2label
model.config.label2id = label2id

# Calculate and print the number of trainable parameters in millions for the model.
print(model.num_parameters(only_trainable=True) / 1e6)
# Out:
# config.json:   0%|          | 0.00/502 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 85.800194

# %%
# Load the accuracy metric from a module named 'evaluate'
accuracy = evaluate.load("accuracy")

# Define a function 'compute_metrics' to calculate evaluation metrics
def compute_metrics(eval_pred):
    # Extract model predictions from the evaluation prediction object
    predictions = eval_pred.predictions

    # Extract true labels from the evaluation prediction object
    label_ids = eval_pred.label_ids

    # Calculate accuracy using the loaded accuracy metric
    # Convert model predictions to class labels by selecting the class with the highest probability (argmax)
    predicted_labels = predictions.argmax(axis=1)

    # Calculate accuracy score by comparing predicted labels to true labels
    acc_score = accuracy.compute(predictions=predicted_labels, references=label_ids)['accuracy']

    # Return the computed accuracy as a dictionary with the key "accuracy"
    return {
        "accuracy": acc_score
    }
# Out:
# Downloading builder script:   0%|          | 0.00/4.20k [00:00<?, ?B/s]

# %%
# Define training arguments
args = TrainingArguments(
    output_dir="Deep-Fake-Detector-v2-Model",
    logging_dir='./logs',
    evaluation_strategy="epoch",
    learning_rate=1e-6,
    per_device_train_batch_size=32,
    per_device_eval_batch_size=8,
    num_train_epochs=2,
    weight_decay=0.02,
    warmup_steps=50,
    remove_unused_columns=False,
    save_strategy='epoch',
    load_best_model_at_end=True,
    save_total_limit=1,
    report_to="none"
)

# %%
# Create a Trainer instance
trainer = Trainer(
    model,
    args,
    train_dataset=train_data,
    eval_dataset=test_data,
    data_collator=collate_fn,
    compute_metrics=compute_metrics,
    tokenizer=processor,
)

# %%
trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='7001' max='7001' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [7001/7001 12:12]
#     </div>
# {'eval_loss': 0.6953830718994141,
#  'eval_model_preparation_time': 0.0045,
#  'eval_accuracy': 0.4956340065355976,
#  'eval_runtime': 734.5409,
#  'eval_samples_per_second': 76.239,
#  'eval_steps_per_second': 9.531}

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='5252' max='5252' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5252/5252 2:05:27, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Model Preparation Time</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.251400</td>
#       <td>0.328844</td>
#       <td>0.004500</td>
#       <td>0.901430</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.194400</td>
#       <td>0.263013</td>
#       <td>0.004500</td>
#       <td>0.921162</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='14002' max='7001' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [7001/7001 1:14:30]
#     </div>
# TrainOutput(global_step=5252, training_loss=0.3096036569634559, metrics={'train_runtime': 7529.7371, 'train_samples_per_second': 22.312, 'train_steps_per_second': 0.698, 'total_flos': 1.3018809239230685e+19, 'train_loss': 0.3096036569634559, 'epoch': 2.0})

# %%
trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='7001' max='7001' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [7001/7001 11:44]
#     </div>
# {'eval_loss': 0.26301252841949463,
#  'eval_model_preparation_time': 0.0045,
#  'eval_accuracy': 0.9211621221049624,
#  'eval_runtime': 704.6584,
#  'eval_samples_per_second': 79.473,
#  'eval_steps_per_second': 9.935,
#  'epoch': 2.0}

# %%
outputs = trainer.predict(test_data)
print(outputs.metrics)
# Out:
# {'test_loss': 0.26301252841949463, 'test_model_preparation_time': 0.0045, 'test_accuracy': 0.9211621221049624, 'test_runtime': 707.3371, 'test_samples_per_second': 79.172, 'test_steps_per_second': 9.898}

# %%
# Extract the true labels from the model outputs
y_true = outputs.label_ids

# Predict the labels by selecting the class with the highest probability
y_pred = outputs.predictions.argmax(1)

# Define a function to plot a confusion matrix
def plot_confusion_matrix(cm, classes, title='Confusion Matrix', cmap=plt.cm.Blues, figsize=(10, 8)):
    """
    This function plots a confusion matrix.

    Parameters:
        cm (array-like): Confusion matrix as returned by sklearn.metrics.confusion_matrix.
        classes (list): List of class names, e.g., ['Class 0', 'Class 1'].
        title (str): Title for the plot.
        cmap (matplotlib colormap): Colormap for the plot.
    """
    # Create a figure with a specified size
    plt.figure(figsize=figsize)

    # Display the confusion matrix as an image with a colormap
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    # Define tick marks and labels for the classes on the axes
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.0f'
    # Add text annotations to the plot indicating the values in the cells
    thresh = cm.max() / 2.0
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    # Label the axes
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

    # Ensure the plot layout is tight
    plt.tight_layout()
    # Display the plot
    plt.show()

# Calculate accuracy and F1 score
accuracy = accuracy_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred, average='macro')

# Display accuracy and F1 score
print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")

# Get the confusion matrix if there are a small number of labels
if len(labels_list) <= 150:
    # Compute the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Plot the confusion matrix using the defined function
    plot_confusion_matrix(cm, labels_list, figsize=(8, 6))

# Finally, display classification report
print()
print("Classification report:")
print()
print(classification_report(y_true, y_pred, target_names=labels_list, digits=4))
# Out:
# Accuracy: 0.9212
# F1 Score: 0.9210
# Classification report:
#
#               precision    recall  f1-score   support
#
#      Realism     0.9683    0.8708    0.9170     28001
#     Deepfake     0.8826    0.9715    0.9249     28000
#
#     accuracy                         0.9212     56001
#    macro avg     0.9255    0.9212    0.9210     56001
# weighted avg     0.9255    0.9212    0.9210     56001

# %%
trainer.save_model()

# %%
# Import the 'pipeline' function from the 'transformers' library.
from transformers import pipeline
pipe = pipeline('image-classification', model=model_name, device=0)

# %%
image = test_data[1]["image"]
image

# %%
pipe(image)

# %%
id2label[test_data[1]["label"]]

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# Import the HfApi class from the huggingface_hub library.
from huggingface_hub import HfApi

api = HfApi()
repo_id = f"prithivMLmods/Deep-Fake-Detector-v2-Model"

try:
    # Attempt to create a new repository on the Hugging Face Model Hub using the specified repo_id.
    api.create_repo(repo_id)

    # If the repository creation is successful, print a message indicating that the repository was created.
    print(f"Repo {repo_id} created")
except:
    # If an exception is raised, print a message indicating that the repository already exists.
    print(f"Repo {repo_id} already exists")
# Out:
# Repo prithivMLmods/Deep-Fake-Detector-v2-Model created

# %%
api.upload_folder(
    folder_path="Deep-Fake-Detector-v2-Model",  # The path to the folder to be uploaded
    path_in_repo=".",  # The path where the folder will be stored in the repository
    repo_id=repo_id,  # The ID of the repository where the folder will be uploaded
    repo_type="model",  # The type of the repository (in this case, a model repository)
    revision="main" # Revision name
)
# Out:
# model.safetensors:   0%|          | 0.00/343M [00:00<?, ?B/s]
# optimizer.pt:   0%|          | 0.00/687M [00:00<?, ?B/s]
# scheduler.pt:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# Upload 7 LFS files:   0%|          | 0/7 [00:00<?, ?it/s]
# rng_state.pth:   0%|          | 0.00/14.2k [00:00<?, ?B/s]
# training_args.bin:   0%|          | 0.00/5.30k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/343M [00:00<?, ?B/s]
# training_args.bin:   0%|          | 0.00/5.30k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/prithivMLmods/Deep-Fake-Detector-v2-Model/commit/c67048e784ca5784020428ae2aa206c3a4d4ea7d', commit_message='Upload folder using huggingface_hub', commit_description='', oid='c67048e784ca5784020428ae2aa206c3a4d4ea7d', pr_url=None, repo_url=RepoUrl('https://huggingface.co/prithivMLmods/Deep-Fake-Detector-v2-Model', endpoint='https://huggingface.co', repo_type='model', repo_id='prithivMLmods/Deep-Fake-Detector-v2-Model'), pr_revision=None, pr_num=None)
